# %% [markdown]
# Insurance Regression

# %%
import numpy as np 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
#import our data
df = pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#select rows from the dataframe for plotting and plot data
plt.scatter(df.iloc[:, 0], df.iloc[:, -1], color = 'b')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
#fit and predict 
simple_model = LinearRegression()
simple_model.fit(x, y)
y_pred = charges_model.predict(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #fit and predict
# ----> 2 simple_model = LinearRegression()
#       3 simple_model.fit(x, y)
#       4 y_pred = charges_model.predict(x)
#
# NameError: name 'LinearRegression' is not defined
